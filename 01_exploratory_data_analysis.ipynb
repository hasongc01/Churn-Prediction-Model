# %% [markdown]
# # 0. Configuration

# %%
# data load
from pathlib import Path # help with folder and file path 

# dataframe
import pandas as pd
from functools import reduce

# %% [markdown]
# # 1. Data Load

# %%
# read files from datasets folder 

def read_df(folder_name):
    ## path object pointing to datasets folder
    folder = Path("datasets") / str(folder_name)

    ## find all files ending in .csv 
    files = list(folder.glob("*.csv")) # glob: method to find files that match pattern 
    ## create list of dataframes for every file 
    dfs = [pd.read_csv(file) for file in files]

    # read each csv to dataframe by taking a list of things and combining into one final

    folder_df = reduce(
        lambda left,right: pd.merge(left,right,on="consumer_id",how="inner"),
        dfs
    ) # drop the first column which is just an index

    return folder_df

# %% [markdown]
# # 1a. User Data

# %%
# load user data 
users_df = read_df("user")

# %%
# see user data
users_df.head(10)
# Out:
#    consumer_id  is_fraudulent latest_changed_password  max_item_count  \
# 0            1              0                   False             2.0
# 1            2              0                   False             1.0
# 2            3              0                     NaN             NaN
# 3            4              0                   False             1.0
# 4            5              0                   False             NaN
# 5            7              0                   False             1.0
# 6            8              0                   False             1.0
# 7            9              0                     NaN             NaN
# 8           10              0                   False             1.0
# 9           11              0                     NaN             1.0
#
#    days_since_first_transaction  email_address_age_days  email_domain_label  \
# 0                     64.653928               51.660825               458.0
# 1                    314.989689              255.116569               386.0
# 2                           NaN                     NaN                 NaN
# 3                    963.831359             1354.169959               386.0
# 4                           NaN              312.916492               386.0
# 5                    314.989689              283.147952              1098.0
# 6                   1609.408568             1766.505844               386.0
# 7                           NaN                0.000000               386.0
# 8                    920.464554             1110.347143               386.0
# 9                    195.541301              259.899353              1100.0
#
#    email_domain_tld_label  email_username_length  \
# 0                    17.0                    7.0
# 1                    17.0                    8.0
# 2                     NaN                    NaN
# 3                    17.0                    9.0
# 4                    17.0                   20.0
# 5                    61.0                   13.0
# 6                    17.0                    9.0
# 7                    17.0                   14.0
# 8                    17.0                   10.0
# 9                    17.0                   11.0
#
#    num_unique_delivery_addresses  latest_delivery_address_name_length  \
# 0                            1.0                                 16.0
# 1                            1.0                                 14.0
# 2                            NaN                                  NaN
# 3                            1.0                                 23.0
# 4                            NaN                                 12.0
# 5                            1.0                                 15.0
# 6                            1.0                                 11.0
# 7                            NaN                                  NaN
# 8                            1.0                                 11.0
# 9                            1.0                                 18.0
#
#    latest_delivery_address_region_label  \
# 0                                  33.0
# 1                                  23.0
# 2                                   NaN
# 3                                  11.0
# 4                                  35.0
# 5                                  15.0
# 6                                   5.0
# 7                                   NaN
# 8                                   5.0
# 9                                   5.0
#
#    latest_delivery_address_fraction_vowels
# 0                                 0.260737
# 1                                 0.234356
# 2                                      NaN
# 3                                 0.438467
# 4                                 0.395141
# 5                                 0.359032
# 6                                 0.157338
# 7                                      NaN
# 8                                 0.398175
# 9                                 0.326991

# %%
# see data types
users_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16485 entries, 0 to 16484
# Data columns (total 13 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   consumer_id                              16485 non-null  int64
#  1   is_fraudulent                            16485 non-null  int64
#  2   latest_changed_password                  11948 non-null  object
#  3   max_item_count                           13274 non-null  float64
#  4   days_since_first_transaction             13203 non-null  float64
#  5   email_address_age_days                   14426 non-null  float64
#  6   email_domain_label                       14426 non-null  float64
#  7   email_domain_tld_label                   14426 non-null  float64
#  8   email_username_length                    14426 non-null  float64
#  9   num_unique_delivery_addresses            11674 non-null  float64
#  10  latest_delivery_address_name_length      14211 non-null  float64
#  11  latest_delivery_address_region_label     14211 non-null  float64
#  12  latest_delivery_address_fraction_vowels  14211 non-null  float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# # 1b. Item Data

# %%
# load item data
item_df = read_df("item")

# %%
# see item data
item_df.head(10)
# Out:
#    consumer_id  latest_order_amount_usd latest_item_category  \
# 0            1               109.667419                  NaN
# 1            2               177.268220                 Soup
# 2            3                      NaN                Sides
# 3            4               144.253218         Fresh Salads
# 4            5                      NaN          Specialties
# 5            7               222.007250      Shareable Sides
# 6            8                90.645562                Sides
# 7            9                      NaN                  NaN
# 8           10               100.974140              Entrees
# 9           11               192.749328    Poultry & Seafood
#
#            latest_item_product_title  latest_item_quantity  \
# 0                                NaN                   NaN
# 1                           Thom Kha                   1.0
# 2                    Mashed Potatoes                   1.0
# 3  Power Greens & Grain Salad - NEW!                   1.0
# 4                   Gordita Supreme®                   1.0
# 5                 Onion Rings (Sack)                   1.0
# 6                       Falafel Side                   1.0
# 7                                NaN                   NaN
# 8                       Burrito Bowl                   1.0
# 9             Boneless Chicken Kabob                   1.0
#
#    latest_item_tag_count
# 0                    NaN
# 1                    0.0
# 2                    1.0
# 3                    1.0
# 4                    1.0
# 5                    1.0
# 6                    1.0
# 7                    NaN
# 8                    1.0
# 9                    1.0

# %%
item_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16485 entries, 0 to 16484
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   consumer_id                16485 non-null  int64
#  1   latest_order_amount_usd    13273 non-null  float64
#  2   latest_item_category       14427 non-null  object
#  3   latest_item_product_title  14427 non-null  object
#  4   latest_item_quantity       14427 non-null  float64
#  5   latest_item_tag_count      14427 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 772.9+ KB

# %% [markdown]
# ## 1c. Activity Data

# %%
activity_df = read_df("activity")

# %%
# see activity data
activity_df.head(10)
# Out:
#    consumer_id  per_week_purchase_total  per_week_unique_ips  \
# 0            1                      NaN                  1.0
# 1            2                    24.73                  1.0
# 2            3                      NaN                  1.0
# 3            4                    64.21                  1.0
# 4            5                      NaN                  1.0
# 5            7                    21.96                  3.0
# 6            8                    48.02                  1.0
# 7            9                      NaN                  1.0
# 8           10                    34.73                  1.0
# 9           11                    31.85                  1.0
#
#    per_week_update_account  per_week_payment_method_change  \
# 0                      4.0                             0.0
# 1                      NaN                             0.0
# 2                      NaN                             0.0
# 3                      NaN                             0.0
# 4                      1.0                             0.0
# 5                      4.0                             0.0
# 6                      NaN                             0.0
# 7                      NaN                             0.0
# 8                      NaN                             0.0
# 9                      NaN                             0.0
#
#    per_day_add_item_to_cart  per_day_transactions  \
# 0                       NaN                   4.0
# 1                       NaN                   1.0
# 2                       4.0                   NaN
# 3                       1.0                   NaN
# 4                       NaN                   NaN
# 5                       NaN                   3.0
# 6                       NaN                   1.0
# 7                       NaN                   NaN
# 8                       NaN                   1.0
# 9                       NaN                   1.0
#
#    per_day_payment_method_change  per_day_devices_per_user  \
# 0                            0.0                       1.0
# 1                            0.0                       1.0
# 2                            0.0                       1.0
# 3                            0.0                       1.0
# 4                            0.0                       1.0
# 5                            0.0                       3.0
# 6                            0.0                       1.0
# 7                            0.0                       1.0
# 8                            0.0                       1.0
# 9                            0.0                       1.0
#
#    per_day_purchase_total  per_day_unique_billing_last4  per_month_logout  \
# 0                     NaN                           1.0               NaN
# 1                   24.73                           NaN               NaN
# 2                     NaN                           NaN               NaN
# 3                    0.00                           NaN               NaN
# 4                     NaN                           NaN               NaN
# 5                   21.96                           1.0               NaN
# 6                   48.02                           NaN               NaN
# 7                     NaN                           NaN               NaN
# 8                   34.73                           1.0               NaN
# 9                   31.85                           NaN               NaN
#
#    per_month_page_activity  per_month_transactions
# 0                      NaN                1.486624
# 1                      NaN                4.483389
# 2                      NaN                     NaN
# 3                      1.0                2.056617
# 4                      NaN                     NaN
# 5                      NaN                4.483389
# 6                      1.0                4.483389
# 7                      NaN                     NaN
# 8                      NaN                0.111225
# 9                      NaN                7.369085

# %%
activity_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16485 entries, 0 to 16484
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   consumer_id                     16485 non-null  int64
#  1   per_week_purchase_total         10843 non-null  float64
#  2   per_week_unique_ips             16485 non-null  float64
#  3   per_week_update_account         8048 non-null   float64
#  4   per_week_payment_method_change  16485 non-null  float64
#  5   per_day_add_item_to_cart        3863 non-null   float64
#  6   per_day_transactions            8978 non-null   float64
#  7   per_day_payment_method_change   16485 non-null  float64
#  8   per_day_devices_per_user        16474 non-null  float64
#  9   per_day_purchase_total          10843 non-null  float64
#  10  per_day_unique_billing_last4    6825 non-null   float64
#  11  per_month_logout                580 non-null    float64
#  12  per_month_page_activity         2480 non-null   float64
#  13  per_month_transactions          11674 non-null  float64
# dtypes: float64(13), int64(1)
# memory usage: 1.8 MB

# %% [markdown]
# ## 2. Simple Distribution

# %%
# see users data summary statistics
users_df.describe().T
# Out:
#                                            count          mean          std  \
# consumer_id                              16485.0  10331.000667  5960.459638
# is_fraudulent                            16485.0      0.065757     0.247864
# max_item_count                           13274.0      1.512430     1.491139
# days_since_first_transaction             13203.0    412.448007   313.353900
# email_address_age_days                   14426.0    439.519107   431.582203
# email_domain_label                       14426.0    508.775475   293.949005
# email_domain_tld_label                   14426.0     19.223901     7.540011
# email_username_length                    14426.0     11.233537     3.349955
# num_unique_delivery_addresses            11674.0      1.273856     0.721794
# latest_delivery_address_name_length      14211.0     12.990571     3.127377
# latest_delivery_address_region_label     14211.0     21.144395    15.155575
# latest_delivery_address_fraction_vowels  14211.0      0.346336     0.113882
#
#                                               min          25%           50%  \
# consumer_id                              1.000000  5160.000000  10350.000000
# is_fraudulent                            0.000000     0.000000      0.000000
# max_item_count                           1.000000     1.000000      1.000000
# days_since_first_transaction             0.178640   250.389598    314.989689
# email_address_age_days                   0.000000   124.043953    281.185836
# email_domain_label                       0.000000   386.000000    386.000000
# email_domain_tld_label                   0.000000    17.000000     17.000000
# email_username_length                    1.000000     9.000000     11.000000
# num_unique_delivery_addresses            1.000000     1.000000      1.000000
# latest_delivery_address_name_length      1.000000    11.000000     13.000000
# latest_delivery_address_region_label     0.000000     5.000000     19.000000
# latest_delivery_address_fraction_vowels  0.000918     0.272959      0.348332
#
#                                                   75%           max
# consumer_id                              15465.000000  20651.000000
# is_fraudulent                                0.000000      1.000000
# max_item_count                               2.000000     50.000000
# days_since_first_transaction               497.100639   2160.582356
# email_address_age_days                     675.078291   3872.999039
# email_domain_label                         575.000000   1128.000000
# email_domain_tld_label                      17.000000     64.000000
# email_username_length                       13.000000     31.000000
# num_unique_delivery_addresses                1.000000     14.000000
# latest_delivery_address_name_length         15.000000     82.000000
# latest_delivery_address_region_label        34.000000     48.000000
# latest_delivery_address_fraction_vowels      0.423575      0.765000

# %% [markdown]
# 1. is_fraudulent
# - Key Statistics: Fraud ratio is about 6.5%
# - Key Learnings: Indicates Class Imbalance
# - Next Steps: Sampling, and modeling process
#
# 2. max_item_count,  email_address_age_days, num_unique_delivery_addresses, latest_delivery_address_name_length
# - Key Statistics: Right skewed
# - Key Learnings: Outliers exist at the upper limit
# - Next Steps: Data Cleaning, check distribution again for fraudulent vs non fraudulent
#
# 3. email_domain_label, email_domain_tld_label
# - Key Learnings: This is nominal categorical values. Values don't seem to indicate real values
# - Next Steps: Data Cleaning

# %%
item_df.describe().T
# Out:
#                            count          mean          std       min  \
# consumer_id              16485.0  10331.000667  5960.459638  1.000000
# latest_order_amount_usd  13273.0    113.704311   113.618403  0.011521
# latest_item_quantity     14427.0      1.141540     0.783290  1.000000
# latest_item_tag_count    14427.0      0.960075     0.195790  0.000000
#
#                                  25%           50%           75%           max
# consumer_id              5160.000000  10350.000000  15465.000000  20651.000000
# latest_order_amount_usd    72.636183    109.667419    111.192081   2985.892208
# latest_item_quantity        1.000000      1.000000      1.000000     30.000000
# latest_item_tag_count       1.000000      1.000000      1.000000      1.000000

# %% [markdown]
# 1. latest_order_amount_usd
# - Key Statistics: Right skewed
# - Key Learnings: Some values are less than $1, may need to replace values.
# - Next Steps: Data Cleaning, check distribution again for fraudulent vs non fraudulent
#
# 2. latest_item_quantity
# - Key Statistics: only values from 75% to max are greater than 1
# - Key Learnings: At least one item is ordered
# - Next Steps: Data Cleaning, check distribution again for fraudulent vs non fraudulent

# %%
activity_df.describe().T
# Out:
#                                   count          mean          std       min  \
# consumer_id                     16485.0  10331.000667  5960.459638  1.000000
# per_week_purchase_total         10843.0     46.812499   139.511627  0.000000
# per_week_unique_ips             16485.0      1.360024     0.789178  1.000000
# per_week_update_account          8048.0      3.610462     4.271304  1.000000
# per_week_payment_method_change  16485.0      0.395814     1.817877  0.000000
# per_day_add_item_to_cart         3863.0      7.563034    11.682184  1.000000
# per_day_transactions             8978.0      1.973379     2.559586  1.000000
# per_day_payment_method_change   16485.0      0.248893     1.298081  0.000000
# per_day_devices_per_user        16474.0      1.222836     0.561463  1.000000
# per_day_purchase_total          10843.0     31.424978   131.251590  0.000000
# per_day_unique_billing_last4     6825.0      1.357363     1.153731  1.000000
# per_month_logout                  580.0      1.437931     1.325169  1.000000
# per_month_page_activity          2480.0      2.441129     1.527139  1.000000
# per_month_transactions          11674.0      5.951365     4.800247  0.002715
#
#                                        25%           50%           75%  \
# consumer_id                     5160.00000  10350.000000  15465.000000
# per_week_purchase_total            1.95000     24.890000     49.270000
# per_week_unique_ips                1.00000      1.000000      1.000000
# per_week_update_account            1.00000      2.000000      4.000000
# per_week_payment_method_change     0.00000      0.000000      0.000000
# per_day_add_item_to_cart           2.00000      3.000000      6.000000
# per_day_transactions               1.00000      1.000000      2.000000
# per_day_payment_method_change      0.00000      0.000000      0.000000
# per_day_devices_per_user           1.00000      1.000000      1.000000
# per_day_purchase_total             0.00000     17.980000     31.810000
# per_day_unique_billing_last4       1.00000      1.000000      1.000000
# per_month_logout                   1.00000      1.000000      1.000000
# per_month_page_activity            1.00000      2.000000      4.000000
# per_month_transactions             3.47054      4.483389      7.301005
#
#                                          max
# consumer_id                     20651.000000
# per_week_purchase_total          7606.630000
# per_week_unique_ips                11.000000
# per_week_update_account            91.000000
# per_week_payment_method_change     46.000000
# per_day_add_item_to_cart           57.000000
# per_day_transactions               33.000000
# per_day_payment_method_change      46.000000
# per_day_devices_per_user            9.000000
# per_day_purchase_total           7606.630000
# per_day_unique_billing_last4       24.000000
# per_month_logout                   19.000000
# per_month_page_activity             5.000000
# per_month_transactions             46.713927

# %% [markdown]
# 1. payment_method_change, per_day_payment_method_change
# - Key Statistics: only values above 75% to max are 46
# - Key Learning: customers that change payment method frequently are rare
# - Next Steps: Check distribution again for fradulent  vs non fradulent (likely that these are fraud)
#
# 2. per_week_purchase_total, per_day_purchase_total, per_month_transactions
# - Key Statistics: highly right skewed
# - Key Learning: these customers may be fradulent or may be high-value customers
#
# 3. per_month_logout, per_day_unique_billing_last4
# - Key Statistics: values between 0 to 75% are just 1 and above 75% are high
# - Key Learning: These may indicate fraud

# %% [markdown]
# # 3. Combine all data to one df

# %%
names = [users_df, item_df, activity_df]

# combine to one df
fraud_df = reduce(lambda left,right: pd.merge(left,right,on='consumer_id',how='inner'), names)

# %%
# see data
fraud_df.head(10)
# Out:
#    consumer_id  is_fraudulent latest_changed_password  max_item_count  \
# 0            1              0                   False             2.0
# 1            2              0                   False             1.0
# 2            3              0                     NaN             NaN
# 3            4              0                   False             1.0
# 4            5              0                   False             NaN
# 5            7              0                   False             1.0
# 6            8              0                   False             1.0
# 7            9              0                     NaN             NaN
# 8           10              0                   False             1.0
# 9           11              0                     NaN             1.0
#
#    days_since_first_transaction  email_address_age_days  email_domain_label  \
# 0                     64.653928               51.660825               458.0
# 1                    314.989689              255.116569               386.0
# 2                           NaN                     NaN                 NaN
# 3                    963.831359             1354.169959               386.0
# 4                           NaN              312.916492               386.0
# 5                    314.989689              283.147952              1098.0
# 6                   1609.408568             1766.505844               386.0
# 7                           NaN                0.000000               386.0
# 8                    920.464554             1110.347143               386.0
# 9                    195.541301              259.899353              1100.0
#
#    email_domain_tld_label  email_username_length  \
# 0                    17.0                    7.0
# 1                    17.0                    8.0
# 2                     NaN                    NaN
# 3                    17.0                    9.0
# 4                    17.0                   20.0
# 5                    61.0                   13.0
# 6                    17.0                    9.0
# 7                    17.0                   14.0
# 8                    17.0                   10.0
# 9                    17.0                   11.0
#
#    num_unique_delivery_addresses  ...  per_week_payment_method_change  \
# 0                            1.0  ...                             0.0
# 1                            1.0  ...                             0.0
# 2                            NaN  ...                             0.0
# 3                            1.0  ...                             0.0
# 4                            NaN  ...                             0.0
# 5                            1.0  ...                             0.0
# 6                            1.0  ...                             0.0
# 7                            NaN  ...                             0.0
# 8                            1.0  ...                             0.0
# 9                            1.0  ...                             0.0
#
#    per_day_add_item_to_cart  per_day_transactions  \
# 0                       NaN                   4.0
# 1                       NaN                   1.0
# 2                       4.0                   NaN
# 3                       1.0                   NaN
# 4                       NaN                   NaN
# 5                       NaN                   3.0
# 6                       NaN                   1.0
# 7                       NaN                   NaN
# 8                       NaN                   1.0
# 9                       NaN                   1.0
#
#    per_day_payment_method_change per_day_devices_per_user  \
# 0                            0.0                      1.0
# 1                            0.0                      1.0
# 2                            0.0                      1.0
# 3                            0.0                      1.0
# 4                            0.0                      1.0
# 5                            0.0                      3.0
# 6                            0.0                      1.0
# 7                            0.0                      1.0
# 8                            0.0                      1.0
# 9                            0.0                      1.0
#
#   per_day_purchase_total  per_day_unique_billing_last4  per_month_logout  \
# 0                    NaN                           1.0               NaN
# 1                  24.73                           NaN               NaN
# 2                    NaN                           NaN               NaN
# 3                   0.00                           NaN               NaN
# 4                    NaN                           NaN               NaN
# 5                  21.96                           1.0               NaN
# 6                  48.02                           NaN               NaN
# 7                    NaN                           NaN               NaN
# 8                  34.73                           1.0               NaN
# 9                  31.85                           NaN               NaN
#
#    per_month_page_activity  per_month_transactions
# 0                      NaN                1.486624
# 1                      NaN                4.483389
# 2                      NaN                     NaN
# 3                      1.0                2.056617
# 4                      NaN                     NaN
# 5                      NaN                4.483389
# 6                      1.0                4.483389
# 7                      NaN                     NaN
# 8                      NaN                0.111225
# 9                      NaN                7.369085
#
# [10 rows x 31 columns]

# %% [markdown]
# # 4. Check Distribution for Fradulent vs Non Fradulent Customers
